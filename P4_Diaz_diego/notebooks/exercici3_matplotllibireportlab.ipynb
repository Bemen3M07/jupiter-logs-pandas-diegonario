# %%
import matplotlib.pyplot as plt

# Crear un gràfic senzill
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y)
plt.title('Exemple de gràfic')
plt.show()

# %%
# !pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 65.7 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from reportlab.pdfgen import canvas

# Crear un document PDF
c = canvas.Canvas("informe.pdf")
c.drawString(100, 750, "Aquest és un informe generat amb ReportLab")
c.save()
print("PDF generat correctament!")
# Out:
# PDF generat correctament!
